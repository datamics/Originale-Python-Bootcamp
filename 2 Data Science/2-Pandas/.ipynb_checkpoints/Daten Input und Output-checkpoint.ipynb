# %% [markdown]
# # Daten Input und Output
#
# Dieses Notebook dient als Referenz, um Input und Output zu erhalten. Pandas kann eine Vielzahl von Dateitypen durch die Methode `pd.read_` lesen. Lasst uns die häufigsten Daten Typen anschauen:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## CSV
# ### CSV Input

# %%
df = pd.read_csv('example')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %% [markdown]
# ### CSV Output

# %%
df.to_csv('example',index=False)

# %% [markdown]
# ## Excel
#
# Pandas kann Excel-Dateien lesen und schreiben. Beachtet aber, dass dabei nur Daten importiert werden. Formeln und Bilder sind dabei nicht eingeschlossen. Makros oder Bilder in der Datei zu haben kann die `read_excel` Methode zum Abstürzen bringen.
#
# ### Excel Input

# %%
pd.read_excel('Excel_Sample.xlsx',sheetname='Sheet1')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-8e76393c7090> in <module>()
# ----> 1 pd.read_excel('Excel_Sample.xlsx',sheetname='Sheet1')
#
# /Users/davidmika/anaconda/envs/python3/lib/python3.6/site-packages/pandas/io/excel.py in read_excel(io, sheetname, header, skiprows, skip_footer, index_col, names, parse_cols, parse_dates, date_parser, na_values, thousands, convert_float, has_index_names, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     201
#     202     if not isinstance(io, ExcelFile):
# --> 203         io = ExcelFile(io, engine=engine)
#     204
#     205     return io._parse_excel(
#
# /Users/davidmika/anaconda/envs/python3/lib/python3.6/site-packages/pandas/io/excel.py in __init__(self, io, **kwds)
#     230     def __init__(self, io, **kwds):
#     231
# --> 232         import xlrd  # throw an ImportError if we need to
#     233
#     234         ver = tuple(map(int, xlrd.__VERSION__.split(".")[:2]))
#
# ModuleNotFoundError: No module named 'xlrd'

# %% [markdown]
# ### Excel Output

# %%
df.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %% [markdown]
# ## HTML
#
# Es ist gut möglich, dass du zuerst die html5lib, lxml und BeautifulSoup4 installieren müsst. In deinem Terminal bzw. deiner Kommandozeile führe folgenden Code aus:
#
#     conda install lxml
#     conda install html5lib
#     conda install BeautifulSoup4
#
# Dann starte das Jupyter Notebook neu.
#
# Pandas kann Tabellen Tabs aus einem HTMl lesen. Zum Beispiel:
#
# ### HTML Input
#
# Pandas `read_html` Methode wird Tabellen aus dem HTML auslesen und eine Liste von Data Frames zurückgeben:

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
df[0]

# %% [markdown]
# ## SQL (optional)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
df.to_sql('data', engine)

# %%
sql_df = pd.read_sql('data',con=engine)

# %%
sql_df

# %% [markdown]
# # Gut gemacht!
