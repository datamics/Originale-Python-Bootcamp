# %% [markdown]
# # Errors und Ausnahmen Hausaufgabe
#
# ## Problem 1
#
# Bearbeite die Ausnahme die der folgende Code produziert, indem du try und except blocks verwendest.

# %%
for i in ['a','b','c']:
    print(i**2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-6ecccec123e7> in <module>()
#       1 for i in ['a','b','c']:
# ----> 2     print(i**2)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %% [markdown]
# ## Problem 2
#
# Bearbeite die Ausnahme die der folgende Code produziert, indem du try und except blocks verwendest. Nutze dann einen finally block um auszugeben "Alles erledigt!".

# %%
x = 5
y = 0

z = x/y
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-3effb78be709> in <module>()
#       2 y = 0
#       3
# ----> 4 z = x/y
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Problem 3
#
# Schreibe eine Funktion, die nach eine Ganzzahl fragt und deren Quadrat als Ergebnis ausgibt (print Anweisung). Nutze eine while Schleife mit try, except und else Block, um auf falsche Eingaben vorbereitet zu sein.

# %%
def ask():
    pass()

# %%
ask()

# %% [markdown]
# ## Gut gemacht!
