# %% [markdown]
# # while Loops
#
# Das <b>while</b> Statement in Python ist einer der allgemeinsten Wege um Iteration durchzuführen. Ein while Statement wird so lange ein einzelnes bzw. eine Gruppe von Statements wiederholen, solange die Bedinung True (wahr) ist. Der Grund aus dem es 'Loop' genannt wird ist, dass Statements so lange wiederholt werden, bis die Bedinung nicht mehr erfüllt wird.
#
# Die allgemeine Form eines while Loops:
#
#     while test:
#         code statement
#     else
#         finales code statement
#
# Lasst und einige einfache Beispiele durchgehen:

# %%
x = 0

while x < 10:
    print 'x ist aktuell: ',x
    print ' x ist immer noch kleiner als 10, 1 zu x hinzufügen'
    x+=1
# Out:
# x ist aktuell:  0
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x ist aktuell:  1
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x ist aktuell:  2
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x ist aktuell:  3
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x ist aktuell:  4
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x ist aktuell:  5
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x ist aktuell:  6
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x ist aktuell:  7
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x ist aktuell:  8
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x ist aktuell:  9
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen

# %% [markdown]
# Schaut euch an, wir oft das print Statement ausgeführt wurde und wie der while Loop so lange weiter gemacht hat, solange die Bedingung (x<10) erfüllt war. Soblad x==10 zutraf stoppte der Code. Folgendes Beispiel zeigt, wie wir ein else Statement einbauen könnten:

# %%
x = 0

while x < 10:
    print 'x ist aktuell: ',x
    print ' x ist immer noch kleiner als 10, 1 zu x hinzufügen'
    x+=1
else:
    print 'Fertig!'
# Out:
# x ist aktuell:  0
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x ist aktuell:  1
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x ist aktuell:  2
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x ist aktuell:  3
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x ist aktuell:  4
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x ist aktuell:  5
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x ist aktuell:  6
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x ist aktuell:  7
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x ist aktuell:  8
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x ist aktuell:  9
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# Fertig!

# %% [markdown]
# ## break, continue, pass
#
# Wir können break, continue and pass Statements in unseren Loops verwenden, um zusätzliche Funktionalität für verschiedenste Fälle einzubauen. Die drei Statements definieren sich folgendermaßen:
#
#     break: Bricht aus dem aktell nähesten umfassenden Loop aus.
#     continue: Geht an den Anfang des nähesten umfassenden Loops.
#     pass: Tut gar nichts.
#
#  Wenn wir über break und continue Statements nachdenken, sieht die allgemeine Form für while Loops wie folgt aus:
#
#     while test:
#         code statement
#         if test:
#             break
#         if test:
#             continue
#     else:
#
# break und continue Statements können überall innerhalb des Loop Bodys eigesetzt werden, wir nutzen sie aber üblicherweise in tieferen Ebenen in Kombination mit if Statements.
#
# Hier sind einige Beispiele:

# %%
x = 0

while x < 10:
    print 'x ist aktuell: ',x
    print ' x ist immer noch kleiner als 10, 1 zu x hinzufügen'
    x+=1
    if x == 3:
        print 'x==3'
    else:
        print 'Fortsetzen...'
        continue
# Out:
# x ist aktuell:  0
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# Fortsetzen...
# x ist aktuell:  1
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# Fortsetzen...
# x ist aktuell:  2
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# x==3
# x ist aktuell:  3
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# Fortsetzen...
# x ist aktuell:  4
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# Fortsetzen...
# x ist aktuell:  5
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# Fortsetzen...
# x ist aktuell:  6
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# Fortsetzen...
# x ist aktuell:  7
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# Fortsetzen...
# x ist aktuell:  8
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# Fortsetzen...
# x ist aktuell:  9
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# Fortsetzen...

# %% [markdown]
# Seht wie wir ein print Statement ausgeführt haben, sobald x == 3 war. Lasst uns nun ein break Statement einbauen, sobald x == 3 erfüllt ist:

# %%
x = 0

while x < 10:
    print 'x ist aktuell: ',x
    print ' x ist immer noch kleiner als 10, 1 zu x hinzufügen'
    x+=1
    if x == 3:
        print 'Bricht ab, da x==3'
        break
    else:
        print 'Fortsetzen...'
        continue
# Out:
# x ist aktuell:  0
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# Fortsetzen...
# x ist aktuell:  1
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# Fortsetzen...
# x ist aktuell:  2
#  x ist immer noch kleiner als 10, 1 zu x hinzufügen
# Bricht ab, da x==3

# %% [markdown]
# Bemerkenswert hieran ist, dass der Code nun endet, sobald break erreicht wird.
#
# Nach diesen kurzen Beispielen solltet ihr euch mit while Loops wohl fühlen und sie guten Gewissens in eurem Code verwenden.
#
# <b>Ein Wort der Warnung: Es ist möglich unendliche Loops mit while Loops zu erstellen. Wie in folgendem Beispiel, das ihr bitte nicht ausführt:</b>

# %%
# Führt diesen Code nicht aus!
while True:
    print 'Oh Oh, unendlicher Loop'
